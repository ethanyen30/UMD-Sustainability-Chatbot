# %%
import pandas as pd
import json

# %%
sus_data = pd.read_json("datafiles/umd_sustainability_data.json")
sus_data
# Out:
#                                                 Link  \
# 0                    https://sustainability.umd.edu/
# 1                    https://sustainability.umd.edu/
# 2                    https://sustainability.umd.edu/
# 3                    https://sustainability.umd.edu/
# 4                    https://sustainability.umd.edu/
# ..                                               ...
# 814  https://sustainability.umd.edu/earth-month-2025
# 815  https://sustainability.umd.edu/earth-month-2025
# 816  https://sustainability.umd.edu/earth-month-2025
# 817  https://sustainability.umd.edu/earth-month-2025
# 818  https://sustainability.umd.edu/earth-month-2025
#
#                             Site_Title  \
# 0            Homepage | SustainableUMD
# 1            Homepage | SustainableUMD
# 2            Homepage | SustainableUMD
# 3            Homepage | SustainableUMD
# 4            Homepage | SustainableUMD
# ..                                 ...
# 814  Earth Month 2025 | SustainableUMD
# ...

# %%
sus_data[sus_data['Content'].str.len() < 100]['Content']
# Out:
# 8      Terp’s Popular ‘Bike Bus’ Promotes Exercise, C...
# 9      3 Docking Stations Near UMD Offer New Connecti...
# 10     Scientists From UMD, Chinese Government Presen...
# 11              Supporting sustainable energy on campus
# 16                            This page is coming soon.
#                              ...
# 854                         Berwyn Historic Walking Tour
# 855                      Lakeland Historic Walking Tour
# 856                  Old Town/Calvert Hills Walking Tour
# 857                        UMD Ghost Tour: Spooky Sites
# 876
# Name: Content, Length: 243, dtype: object

# %%
susprog_data = pd.read_json("umd_sustainingprogress_data.json")
susprog_data
# Out:
#                                                   Link  \
# 0                  https://sustainingprogress.umd.edu/
# 1                  https://sustainingprogress.umd.edu/
# 2                  https://sustainingprogress.umd.edu/
# 3                  https://sustainingprogress.umd.edu/
# 4                  https://sustainingprogress.umd.edu/
# ..                                                 ...
# 994  https://sustainingprogress.umd.edu/guiding-com...
# 995  https://sustainingprogress.umd.edu/guiding-com...
# 996  https://sustainingprogress.umd.edu/guiding-com...
# 997  https://sustainingprogress.umd.edu/guiding-com...
# 998  https://sustainingprogress.umd.edu/keeping-our...
#
#                                             Site_Title  \
# 0    SustainableUMD Progress Hub | Office of Sustai...
# 1    SustainableUMD Progress Hub | Office of Sustai...
# 2    SustainableUMD Progress Hub | Office of Sustai...
# 3    SustainableUMD Progress Hub | Office of Sustai...
# ...
